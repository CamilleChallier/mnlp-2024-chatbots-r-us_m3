# %%
from data_generation import *
import os

# %%
import os
# file_list = os.listdir('data/exams/info_secu_priva')  
# file_list = ['data/exams/info_secu_priva/'+file for file in file_list]
# data_info = extract_many_exams(file_list, extract_data_info_secu_priva)   

file_list = os.listdir('data/exams/crypto_secu/')  
file_list = ['data/exams/crypto_secu/'+file for file in file_list]
data_crypto = extract_many_exams(file_list, extract_data_crypto_secu)  

# file_list = os.listdir('data/exams/ope_syst/')  
# file_list = ['data/exams/ope_syst/'+file for file in file_list]
# data_secu = extract_many_exams(file_list, extract_data_ope_sys)  

# data = data_crypto
# import json
# with open('data/data_exams.json', 'w') as f:
#     json.dump(data, f)

# %%
file_list = os.listdir('data/exams/ML1/')  
file_list = ['data/exams/ML1/'+file for file in file_list]
data_ml1 = extract_many_exams(file_list, extract_data_ml)

# %%
file_list = os.listdir('data/exams/ML2/')  
file_list = ['data/exams/ML2/'+file for file in file_list]
data_ml = extract_many_exams(file_list, extract_data_ml2)  

len(data_ml)
# Out:
# 44

# %%
file_list = os.listdir('data/exams/ph/')  
file_list_a = ['data/exams/ph/'+file for file in file_list if file.endswith('ol.pdf')]
file_list_q = ['data/exams/ph/'+file for file in file_list if not file.endswith('ol.pdf')]
data_ph = extract_many_exams_double(file_list_q, file_list_a, extract_data_ph)

# %%
len(data_ph)
# Out:
# 79

# %%
data_ph
# Out:
# [{'question': 'A ball of mass  m 1  is traveling with a horizontal velocity  v 0  and hits a second ball of mass  m 2 . This second ball is initially hanging on a vertical cord of length  L . What is the maximum height attained by the second ball in the following cases: 1. The collision between the two balls is perfectly elastic 2. The collision between the two balls is inelastic and they stick together Numerical application:  m 1  = 0 . 1  kg,  m 2  = 0 . 2  kg,  L  = 30  cm,  v 0  = 1  m/s. L v 0 m 1 m 2 ',
# ...

# %%
import json
f = open('data/data_exams_best3.json')
 
# returns JSON object as 
# a dictionary
data_exams = json.load(f)
print(len(data_exams))
data = data_ph + data_exams
print(len(data))
import json
with open('data/data_exams_best4.json', 'w') as f:
    json.dump(data, f)
# Out:
# 479
# 558
